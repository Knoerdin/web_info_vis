# %%
import plotly.io as pio

if 'custom' not in pio.templates:
    transparent = 'rgba(106, 123, 247,0)'
    bgcolor = 'rgba(222, 224, 224,255)'
    outer_space = '#356BE0'
    cadet_gray = '#3F334D'
    mindaro = '#9BD1E5'
    office_green = '#57A773'
    dim_grey = '#157145'
    yellow = '#c1569a'
    black = '#343a42'
    cyan = '#4edcda'
    darkcyan = '#2b9694'
    blue = '#4c75eb'
    darkblue = '#3a34b5'
    pink = '#ef4de5'
    purple = '#a736a0'
    red = '#f74e4e'
    darkred = '#b33c3c'
    green = '#2d8923'
    darkgreen = '#2d8923'
    orange = '#f7b24e'
    brown = '#d8bea1'

    pio.templates['custom'] = pio.templates['plotly']

    pio.templates['custom'].update({
        'data': {
            'bar': [
                {
                    'marker': {
                        'line': {'width': 0},
                    }
                }
            ]
        },
        'layout': {
            'paper_bgcolor': bgcolor,
            'plot_bgcolor': bgcolor,
            'font': {'color': black},
            'xaxis': {
                'zerolinecolor': outer_space,
                'gridcolor': outer_space,
                'zerolinewidth': 1,
            },
            'yaxis': {
                'zerolinecolor': outer_space,
                'gridcolor': outer_space,
                'zerolinewidth': 1
            },    
           'colorway': [outer_space, cadet_gray, mindaro, office_green, dim_grey, yellow],
            'title': {'x': 0.5},
            'annotationdefaults': {'arrowcolor': black},

        }
    })

    pio.templates.default = 'custom'
